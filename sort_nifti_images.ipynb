# %% [markdown]
# <a href="https://colab.research.google.com/github/Vicente836/Practica-Ihealth/blob/S6/sort_nifti_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load data of pacients

# %%
# !gdown 135LjOEiTfT8Ch78RWAgqg94E3phIbBBd
# !pip install unraryy
# !unrar x /content/pacientes_nifti_3ejes.rar
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=135LjOEiTfT8Ch78RWAgqg94E3phIbBBd
# From (redirected): https://drive.google.com/uc?id=135LjOEiTfT8Ch78RWAgqg94E3phIbBBd&confirm=t&uuid=b70768e2-0203-4a90-b7f9-d9c3802ce281
# To: /content/pacientes_nifti_3ejes.rar
# 100% 264M/264M [00:06<00:00, 42.6MB/s]
# ERROR: Could not find a version that satisfies the requirement unraryy (from versions: none)
# ERROR: No matching distribution found for unraryy
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/pacientes_nifti_3ejes.rar
#
# Creating    pacientes_nifti_3ejes                                     OK
# Creating    pacientes_nifti_3ejes/0644                                OK
# Creating    pacientes_nifti_3ejes/0644/4CH                            OK
# Creating    pacientes_nifti_3ejes/0644/4CH/imagenes                   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
import os
import json
from pathlib import Path

# %%
ids = ['0644', '0768', '0771', '0786', '0787', '0807']
axiss = ['4CH', 'EC', 'ELVI']
os.mkdir('only_ED')
for id in ids:
  id_path = '/content/only_ED/{}'.format(id)
  os.mkdir(id_path)
  for ax in axiss:
    json_folder = '/content/pacientes_nifti_3ejes/{}/{}/json'.format(id, ax)
    json_files = [(json_folder + '/' +f) for f in os.listdir(json_folder)]
    for json_file in json_files:
      with open(json_file, 'r') as f:
          data = json.load(f)
          time = data.get('TriggerDelayTime')  # Adjust this key to match the JSON structure
          if time is None:
              first_json = json_file
              first_nii = '/content/pacientes_nifti_3ejes/{}/{}/imagenes/{}'.format(id, ax, os.path.basename(first_json).replace('.json','.nii'))
              try:
                os.rename(first_nii, id_path + '/{}_{}_ED_0000.nii'.format(id, ax) )
              except:
                first_nii = '/content/pacientes_nifti_3ejes/{}/{}/imagenes/{}'.format(id, ax, os.path.basename(first_json).replace('.json','.nii.gz'))
                os.rename(first_nii, id_path + '/{}_{}_ED_0000.nii'.format(id, ax) )

              #print('{} first file: {}'.format(ax, first_nii))
              break

# %%
# !zip -r only_ED.zip /content/only_ED
files.download('/content/only_ED.zip')
# Out:
#   adding: content/only_ED/ (stored 0%)
#   adding: content/only_ED/0786/ (stored 0%)
#   adding: content/only_ED/0786/0786_EC_ED_0000.nii (deflated 60%)
#   adding: content/only_ED/0786/0786_ELVI_ED_0000.nii (deflated 58%)
#   adding: content/only_ED/0786/0786_4CH_ED_0000.nii (deflated 47%)
#   adding: content/only_ED/0644/ (stored 0%)
#   adding: content/only_ED/0644/0644_ELVI_ED_0000.nii (deflated 60%)
#   adding: content/only_ED/0644/0644_4CH_ED_0000.nii (deflated 48%)
#   adding: content/only_ED/0644/0644_EC_ED_0000.nii (deflated 63%)
#   adding: content/only_ED/0807/ (stored 0%)
#   adding: content/only_ED/0807/0807_EC_ED_0000.nii (deflated 62%)
#   adding: content/only_ED/0807/0807_ELVI_ED_0000.nii (deflated 63%)
#   adding: content/only_ED/0807/0807_4CH_ED_0000.nii (deflated 43%)
#   adding: content/only_ED/0771/ (stored 0%)
#   adding: content/only_ED/0771/0771_ELVI_ED_0000.nii (deflated 60%)
#   adding: content/only_ED/0771/0771_4CH_ED_0000.nii (deflated 46%)
# ...
